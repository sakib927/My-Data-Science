# %% [markdown]
# <a href="https://colab.research.google.com/github/sakib927/My-Data-Science/blob/main/Cars_data_set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('/content/drive/MyDrive/cars_sampled.csv')

# %%
data1 =  data.copy(deep=True)

# %%
data1.head()
# Out:
#         dateCrawled                                               name  \
# 0  30/03/2016 13:51                                       Zu_verkaufen
# 1     7/3/2016 9:54                             Volvo_XC90_2.4D_Summum
# 2     1/4/2016 0:57                                  Volkswagen_Touran
# 3  19/03/2016 17:50                       Seat_Ibiza_1.4_16V_Reference
# 4  16/03/2016 14:51  Volvo_XC90_D5_Aut._RDesign_R_Design_AWD_GSHD_S...
#
#     seller offerType  price   abtest vehicleType  yearOfRegistration  \
# 0  private     offer   4450     test   limousine                2003
# 1  private     offer  13299  control         suv                2005
# 2  private     offer   3200     test         bus                2003
# 3  private     offer   4500  control   small car                2006
# 4  private     offer  18750     test         suv                2008
#
#      gearbox  powerPS     model  kilometer  monthOfRegistration fuelType  \
# ...

# %%
data1.dtypes
# Out:
# dateCrawled            object
# name                   object
# seller                 object
# offerType              object
# price                   int64
# abtest                 object
# vehicleType            object
# yearOfRegistration      int64
# gearbox                object
# powerPS                 int64
# model                  object
# kilometer               int64
# monthOfRegistration     int64
# fuelType               object
# brand                  object
# notRepairedDamage      object
# dateCreated            object
# postalCode              int64
# lastSeen               object
# dtype: object

# %%
data1.describe()
# Out:
#               price  yearOfRegistration       powerPS      kilometer  \
# count  5.000100e+04        50001.000000  50001.000000   50001.000000
# mean   6.559865e+03         2005.544229    116.496130  125613.687726
# std    8.581847e+04          122.991832    230.567709   40205.234483
# min    0.000000e+00         1000.000000      0.000000    5000.000000
# 25%    1.150000e+03         1999.000000     69.000000  125000.000000
# 50%    2.950000e+03         2003.000000    105.000000  150000.000000
# 75%    7.190000e+03         2008.000000    150.000000  150000.000000
# max    1.234568e+07         9999.000000  19312.000000  150000.000000
#
#        monthOfRegistration    postalCode
# count         50001.000000  50001.000000
# mean              5.743725  50775.216696
# std               3.711345  25743.701933
# min               0.000000   1067.000000
# 25%               3.000000  30559.000000
# 50%               6.000000  49504.000000
# 75%               9.000000  71404.000000
# ...

# %%
data1.round(3)
# Out:
#             dateCrawled                                               name  \
# 0      30/03/2016 13:51                                       Zu_verkaufen
# 1         7/3/2016 9:54                             Volvo_XC90_2.4D_Summum
# 2         1/4/2016 0:57                                  Volkswagen_Touran
# 3      19/03/2016 17:50                       Seat_Ibiza_1.4_16V_Reference
# 4      16/03/2016 14:51  Volvo_XC90_D5_Aut._RDesign_R_Design_AWD_GSHD_S...
# ...                 ...                                                ...
# 49996    3/4/2016 15:48                               Suche_VW_T5_Multivan
# 49997  27/03/2016 14:55  Suche_einen_originalen_VW_Golf_2_Fire_and_Ice_G60
# 49998  14/03/2016 18:51  [SUCHE]_BMW_e46_Coupe_330ci_M_Paket_Facelift__...
# 49999  15/03/2016 18:06        Verkaufe_mehrere_Fahrzeuge_zum_Verschrotten
# 50000   22/03/2016 9:54                    Chevrolet_Matiz_1.Hd_TÜV11/2017
#
#            seller offerType  price   abtest    vehicleType  \
# ...

# %%
data.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'postalCode', 'lastSeen'],
#       dtype='object')

# %%
data1 =data1.drop(columns = ['name','dateCrawled', 'dateCreated', 'postalCode', 'lastSeen'])

# %%
data1.head()
# Out:
#     seller offerType  price   abtest vehicleType  yearOfRegistration  \
# 0  private     offer   4450     test   limousine                2003
# 1  private     offer  13299  control         suv                2005
# 2  private     offer   3200     test         bus                2003
# 3  private     offer   4500  control   small car                2006
# 4  private     offer  18750     test         suv                2008
#
#      gearbox  powerPS     model  kilometer  monthOfRegistration fuelType  \
# 0     manual      150       3er     150000                    3   diesel
# 1     manual      163  xc_reihe     150000                    6   diesel
# 2     manual      101    touran     150000                   11   diesel
# 3     manual       86     ibiza      60000                   12   petrol
# 4  automatic      185  xc_reihe     150000                   11   diesel
#
#         brand notRepairedDamage
# 0         bmw               NaN
# 1       volvo                no
# ...

# %%
data1 = data1.drop_duplicates(subset = None,keep = "first")

# %%
data1 = data1.sort_values(by = ['yearOfRegistration'],ascending = [True])

# %%
data1.head(10)
# Out:
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# 43043  private     offer      0     test         NaN                1000
# 12768  private     offer    550  control         NaN                1000
# 7150   private     offer    400     test         NaN                1000
# 25449  private     offer     20  control         NaN                1000
# 8027   private     offer   4750  control         NaN                1000
# 41464  private     offer  16500  control         NaN                1000
# 45635  private     offer    100  control         NaN                1255
# 42868  private     offer      0  control         NaN                1500
# 37292  private     offer    450  control         NaN                1500
# 27369  private     offer     99     test         NaN                1910
#
#       gearbox  powerPS   model  kilometer  monthOfRegistration fuelType  \
# 43043     NaN        0     NaN       5000                    0      NaN
# ...

# %%
data1.groupby(by = 'yearOfRegistration').sum()
# Out:
#                       price  powerPS  kilometer  monthOfRegistration
# yearOfRegistration
# 1000                  22220     1000      30000                    6
# 1255                    100        0       5000                    0
# 1500                    450        0      10000                    0
# 1910                   5089      230     455000                    2
# 1928                   5200        0       5000                    0
# ...                     ...      ...        ...                  ...
# 7500                      0        0      10000                    0
# 7800                   9500        0      10000                    0
# 8500                   6499        0      10000                    0
# 8888                 129956        0      20000                    0
# 9999                1028348        0      70000                    1
#
# [97 rows x 4 columns]

# %%
data1.groupby(by = 'yearOfRegistration').count()
# Out:
#                     seller  offerType  price  abtest  vehicleType  gearbox  \
# yearOfRegistration
# 1000                     6          6      6       6            0        0
# 1255                     1          1      1       1            0        0
# 1500                     2          2      2       2            0        1
# 1910                    14         14     14      14            0        3
# 1928                     1          1      1       1            1        0
# ...                    ...        ...    ...     ...          ...      ...
# 7500                     1          1      1       1            0        1
# 7800                     1          1      1       1            0        0
# 8500                     1          1      1       1            0        0
# 8888                     2          2      2       2            0        0
# 9999                     7          7      7       7            0        0
#
# ...

# %%
data1 = data1[(data1['yearOfRegistration']>1950)&(data1['yearOfRegistration']<2018)]

# %%
data1 = data1[(data1['price']>=100)&(data1['price']<=150000)]

# %%
data1 = data1[(data1['powerPS']>=10)&(data1['powerPS']<=500)]

# %%
data1[['Age']]=0
data1['Age'] = (2018 - ((data1["monthOfRegistration"]/12) + data1["yearOfRegistration"]))

# %%
data1
# Out:
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# 31753  private     offer  17900     test   limousine                1951
# 43408  private     offer  29900     test      cabrio                1951
# 30651  private     offer   4500     test   limousine                1951
# 45201  private     offer   3500     test         suv                1953
# 9330   private     offer  11500     test   limousine                1954
# ...        ...       ...    ...      ...         ...                 ...
# 8886   private     offer   5299  control         NaN                2017
# 7707   private     offer   8600  control         NaN                2017
# 4774   private     offer   3300     test         NaN                2017
# 10563  private     offer   1150  control         NaN                2017
# 17173  private     offer   1000     test         NaN                2017
#
#       gearbox  powerPS    model  kilometer  monthOfRegistration fuelType  \
# ...

# %%
data1 .describe()
# Out:
#                price  yearOfRegistration       powerPS      kilometer  \
# count   42383.000000        42383.000000  42383.000000   42383.000000
# mean     6156.021636         2003.495033    126.226695  125773.895194
# std      7971.451624            6.990371     60.593578   39098.398052
# min       100.000000         1951.000000     10.000000    5000.000000
# 25%      1450.000000         1999.000000     80.000000  100000.000000
# 50%      3500.000000         2004.000000    116.000000  150000.000000
# 75%      7900.000000         2008.000000    150.000000  150000.000000
# max    149000.000000         2017.000000    500.000000  150000.000000
#
#        monthOfRegistration           Age
# count         42383.000000  42383.000000
# mean              5.999316     14.005024
# std               3.574817      7.004006
# min               0.000000      0.000000
# 25%               3.000000      9.416667
# 50%               6.000000     13.833333
# 75%               9.000000     18.166667
# ...

# %%
data1 =data1.drop(columns = ['yearOfRegistration','monthOfRegistration'])

# %%
data1
# Out:
#         seller offerType  price   abtest vehicleType gearbox  powerPS  \
# 31753  private     offer  17900     test   limousine  manual       58
# 43408  private     offer  29900     test      cabrio  manual       54
# 30651  private     offer   4500     test   limousine     NaN       39
# 45201  private     offer   3500     test         suv  manual       72
# 9330   private     offer  11500     test   limousine     NaN      150
# ...        ...       ...    ...      ...         ...     ...      ...
# 8886   private     offer   5299  control         NaN  manual      110
# 7707   private     offer   8600  control         NaN  manual      150
# 4774   private     offer   3300     test         NaN     NaN       75
# 10563  private     offer   1150  control         NaN  manual      130
# 17173  private     offer   1000     test         NaN     NaN       15
#
#          model  kilometer fuelType           brand notRepairedDamage  \
# ...

# %%
from matplotlib import pyplot as plt
plt.plot(data1["Age"],data1["price"])
plt.show()
'''
age is a censitive to price so its needed
'''
# Out:
# '\nage is a censitive to price so its needed\n'

# %%
'''from matplotlib import pyplot as plt
plt.plot(data1["seller"],data1["price"])
plt.show()'''

data1['seller'].value_counts()
pd.crosstab(data1["seller"],columns = 'count', normalize= True)
sns.countplot(x= 'seller',data = data1)

# %%
'''from matplotlib import pyplot as plt
plt.plot(data1["offerType"],data1["price"])
plt.show()'''

data1['offerType'].value_counts()
pd.crosstab(data1["offerType"],columns = 'count', normalize= True)
sns.countplot(x= 'offerType',data = data1)

# %%
'''from matplotlib import pyplot as plt
plt.plot(data1["abtest"],data1["price"])
plt.show()'''

data1['abtest'].value_counts()
pd.crosstab(data1["abtest"],columns = 'count', normalize= True)
sns.countplot(x= 'abtest',data = data1)

# %%
'''from matplotlib import pyplot as plt
plt.plot(data1["vehicleType"],data1["price"])
plt.show()'''

data1['vehicleType'].value_counts()
pd.crosstab(data1["vehicleType"],columns = 'count', normalize= True)
sns.countplot(x= 'vehicleType',data = data1)
sns.boxplot(x ='vehicleType',y = 'price',data = data1 )

# %%
data1['vehicleType'].value_counts()
pd.crosstab(data1["vehicleType"],columns = 'count', normalize= True)
sns.countplot(x= 'vehicleType',data = data1)

# %%
'''from matplotlib import pyplot as plt
plt.plot(data1["gearbox"],data1["price"])
plt.show()'''

data1['gearbox'].value_counts()
pd.crosstab(data1["gearbox"],columns = 'count', normalize= True)
sns.countplot(x= 'gearbox',data = data1)
sns.boxplot(x ='gearbox',y = 'price',data = data1 )

# %%
'''from matplotlib import pyplot as plt
plt.plot(data1["model"],data1["price"])
plt.show()'''
data1['model'].value_counts()
pd.crosstab(data1["model"],columns = 'count', normalize= True)
sns.countplot(x= 'model',data = data1)
sns.boxplot(x ='model',y = 'price',data = data1 )

# %%
data1['model'].value_counts()
pd.crosstab(data1["model"],columns = 'count', normalize= True)
sns.countplot(x= 'model',data = data1)

# %%
'''from matplotlib import pyplot as plt
plt.plot(data1["kilometer"],data1["price"])
plt.show()'''

data1['kilometer'].value_counts()
pd.crosstab(data1["kilometer"],columns = 'count', normalize= True)
sns.countplot(x= 'kilometer',data = data1)
sns.boxplot(x= 'kilometer', y = 'price',data = data1)

# %%
data1['kilometer'].value_counts()
pd.crosstab(data1["kilometer"],columns = 'count', normalize= True)
sns.countplot(x= 'kilometer',data = data1)

# %%
'''from matplotlib import pyplot as plt
plt.plot(data1["fuelType"],data1["price"])
plt.show()'''
data1['fuelType'].value_counts()
pd.crosstab(data1["fuelType"],columns = 'count', normalize= True)
sns.countplot(x= 'fuelType',data = data1)
sns.boxplot(x= 'fuelType', y = 'price',data = data1)

# %%
'''from matplotlib import pyplot as plt
plt.plot(data1["brand"],data1["price"])
plt.show()'''


data1['brand'].value_counts()
pd.crosstab(data1["brand"],columns = 'count', normalize= True)
sns.countplot(x= 'brand',data = data1)
sns.boxplot(x= 'brand', y = 'price',data = data1)

# %%
data1
# Out:
#         seller offerType  price   abtest vehicleType gearbox  powerPS  \
# 31753  private     offer  17900     test   limousine  manual       58
# 43408  private     offer  29900     test      cabrio  manual       54
# 30651  private     offer   4500     test   limousine     NaN       39
# 45201  private     offer   3500     test         suv  manual       72
# 9330   private     offer  11500     test   limousine     NaN      150
# ...        ...       ...    ...      ...         ...     ...      ...
# 8886   private     offer   5299  control         NaN  manual      110
# 7707   private     offer   8600  control         NaN  manual      150
# 4774   private     offer   3300     test         NaN     NaN       75
# 10563  private     offer   1150  control         NaN  manual      130
# 17173  private     offer   1000     test         NaN     NaN       15
#
#          model  kilometer fuelType           brand notRepairedDamage  \
# ...

# %%
'''
from matplotlib import pyplot as plt
plt.plot(data1["notRepairedDamage"],data1["price"])
plt.show()'''


data1['notRepairedDamage'].value_counts()
pd.crosstab(data1["notRepairedDamage"],columns = 'count', normalize= True)
sns.countplot(x= 'notRepairedDamage',data = data1)
sns.boxplot(x= 'notRepairedDamage', y = 'price',data = data1)

# %%
data1 = data1.drop(columns = ['offerType','seller','abtest'])

# %%
data1
# Out:
#        price vehicleType gearbox  powerPS    model  kilometer fuelType  \
# 31753  17900   limousine  manual       58   others      50000   petrol
# 43408  29900      cabrio  manual       54      NaN      90000   petrol
# 30651   4500   limousine     NaN       39   others      80000      NaN
# 45201   3500         suv  manual       72   others     150000   petrol
# 9330   11500   limousine     NaN      150   others     125000   petrol
# ...      ...         ...     ...      ...      ...        ...      ...
# 8886    5299         NaN  manual      110  3_reihe     150000   petrol
# 7707    8600         NaN  manual      150   zafira     150000   diesel
# 4774    3300         NaN     NaN       75     golf     150000      NaN
# 10563   1150         NaN  manual      130   mondeo     150000      NaN
# 17173   1000         NaN     NaN       15      NaN       5000      NaN
#
#                 brand notRepairedDamage        Age
# 31753         citroen                no  66.500000
# ...

# %%
data1_select1 = data1.select_dtypes(exclude = [object])
correlation = data1_select1.corr()
print(correlation)
'''
round(correlation,3)
data1_select1.corr().loc[:,'price'].abs().sort_values(ascending = False)[1:]'''
# Out:
#               price   powerPS  kilometer       Age
# price      1.000000  0.575410  -0.440937 -0.351860
# powerPS    0.575410  1.000000  -0.014573 -0.164004
# kilometer -0.440937 -0.014573   1.000000  0.302299
# Age       -0.351860 -0.164004   0.302299  1.000000
# "\nround(correlation,3)\ndata1_select1.corr().loc[:,'price'].abs().sort_values(ascending = False)[1:]"

# %%
round(correlation,3)
# Out:
#            price  powerPS  kilometer    Age
# price      1.000    0.575     -0.441 -0.352
# powerPS    0.575    1.000     -0.015 -0.164
# kilometer -0.441   -0.015      1.000  0.302
# Age       -0.352   -0.164      0.302  1.000

# %%
data1_select1.corr().loc[:,'price'].abs().sort_values(ascending = False)[1:]
# Out:
# powerPS      0.575410
# kilometer    0.440937
# Age          0.351860
# Name: price, dtype: float64

# %%
data1.isnull().sum()
# Out:
# price                   0
# vehicleType          2488
# gearbox               766
# powerPS                 0
# model                1642
# kilometer               0
# fuelType             2438
# brand                   0
# notRepairedDamage    6132
# Age                     0
# dtype: int64

# %%
data1_omit = data1.dropna(axis=0)

# %%
data1_omit.isnull().sum()
# Out:
# price                0
# vehicleType          0
# gearbox              0
# powerPS              0
# model                0
# kilometer            0
# fuelType             0
# brand                0
# notRepairedDamage    0
# Age                  0
# dtype: int64

# %%
data1_omit = pd.get_dummies(data1_omit,drop_first = True)

# %%
data1_omit
# Out:
#         price  powerPS  kilometer        Age  vehicleType_cabrio  \
# 31753   17900       58      50000  66.500000                   0
# 45201    3500       72     150000  64.166667                   0
# 23407  149000      213       5000  62.416667                   1
# 45747    9700       75     150000  62.500000                   0
# 4255    11800       56      60000  62.500000                   0
# ...       ...      ...        ...        ...                 ...
# 10447   34000      184       5000   1.750000                   0
# 37869   19950      120       5000   1.916667                   0
# 40473  122500      375       5000   1.750000                   1
# 20255   27900      181       5000   1.916667                   0
# 40376   11950      130     150000   0.416667                   0
#
#        vehicleType_coupe  vehicleType_limousine  vehicleType_others  \
# 31753                  0                      1                   0
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
x1 = data1_omit.drop(['price'], axis='columns', inplace=False)
y1 = data1_omit['price']

prices = pd.DataFrame({"1. Before":y1, "2. After":np.log(y1)})
prices.hist()

y1 = np.log(y1)

X_train, X_test, y_train, y_test = train_test_split(x1, y1, test_size=0.3, random_state = 3)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (23018, 300) (9865, 300) (23018,) (9865,)

# %%
# Setting intercept as true
lgr=LinearRegression(fit_intercept=True)

# Model
model_lin1=lgr.fit(X_train,y_train)

# Predicting model on test set
cars_predictions_lin1 = lgr.predict(X_test)

# Computing MSE and RMSE
lin_mse1 = mean_squared_error(y_test, cars_predictions_lin1)
lin_rmse1 = np.sqrt(lin_mse1)
print(lin_rmse1)

# R squared value
r2_lin_test1=model_lin1.score(X_test,y_test)
r2_lin_train1=model_lin1.score(X_train,y_train)
print(r2_lin_test1,r2_lin_train1)

# Regression diagnostics- Residual plot analysis
residuals1=y_test-cars_predictions_lin1
sns.regplot(x=cars_predictions_lin1, y=residuals1, scatter=True, 
            fit_reg=False)
residuals1.describe()
# Out:
# 0.5435755785829924
# 0.7712687169626118 0.7788638758357825
# count    9865.000000
# mean       -0.011421
# std         0.543483
# min        -6.081540
# 25%        -0.267671
# 50%         0.033252
# 75%         0.284487
# max         4.616335
# Name: price, dtype: float64
